# %% [markdown]
# This model is implemented using Polyp Data Set by using below reference -
#
#  https://medium.com/@anirudh.s.chakravarthy/training-yolov3-on-your-custom-dataset-19a1abbdaf09

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ln -s /content/gdrive/My\ Drive/ /mydrive

# %%
# %cd /mydrive/yolov3
# Out:
# /content/gdrive/My Drive/yolov3

# %%
# !git clone https://github.com/AlexeyAB/darknet.git
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15412, done.
# remote: Total 15412 (delta 0), reused 0 (delta 0), pack-reused 15412
# Receiving objects: 100% (15412/15412), 14.04 MiB | 6.27 MiB/s, done.
# Resolving deltas: 100% (10356/10356), done.
# Checking out files: 100% (2050/2050), done.

# %%
# !cp -R /content/gdrive/MyDrive/yolov4/darknet/data/obj /content/gdrive/MyDrive/yolov3/darknet/data

# %%
# !cp -R /content/gdrive/MyDrive/yolov4/training/obj /content/gdrive/MyDrive/yolov3/darknet/data/

# %%
# !cp -R /content/gdrive/MyDrive/yolor-main/dataset/labels/train /content/gdrive/MyDrive/yolov4/training/obj

# %%
# %cd darknet/
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile
# !sed -i 's/LIBSO=0/LIBSO=1/' Makefile
# Out:
# /content/gdrive/My Drive/yolov3/darknet

# %%
# !make

# %%
# %rm -rf cfg/
# %mkdir cfg

# %%
# %cd data/
# !find -maxdepth 1 -type f -exec rm -rf {} \;
# %cd ..
# Out:
# /content/gdrive/MyDrive/yolov3/darknet/data
# /content/gdrive/MyDrive/yolov3/darknet

# %%
# !zip -r /content/gdrive/MyDrive/yolov4/training/obj.zip /content/gdrive/MyDrive/yolov4/training/obj

# %%
# !unzip /content/gdrive/MyDrive/yolov4/training/obj.zip -d data/

# %%
# !cp /content/gdrive/MyDrive/yolov3/yolov3-voc-custom.cfg cfg

# %%
# !cp /mydrive/yolov3/obj.names data
# !cp /mydrive/yolov3/obj.data  data

# %%
# !cp /mydrive/yolov3/train.txt  data
# !cp /mydrive/yolov3/test.txt  data

# %%
# !cp /mydrive/yolov3/training/obj  data/obj
# Out:
# cp: -r not specified; omitting directory '/mydrive/yolov3/training/obj'

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2022-05-06 14:18:27--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74.1’
#
# darknet53.conv.74.1 100%[===================>] 154.96M  38.8MB/s    in 4.5s
#
# 2022-05-06 14:18:32 (34.8 MB/s) - ‘darknet53.conv.74.1’ saved [162482580/162482580]

# %%
#Command to start the training
# !./darknet detector train data/obj.data cfg/yolov3-voc-custom.cfg darknet53.conv.74 -clear 1 -dont_show -map
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000003, iou_loss = 0.000000, total_loss = 0.000003
#  total_bbox = 133677, rewritten_bbox = 0.000000 %
#
#  (next mAP calculation at 2000 iterations)
#  Last accuracy mAP@0.50 = 81.85 %, best = 81.85 %
#  1981: 0.089765, 0.105011 avg loss, 0.000010 rate, 6.886208 seconds, 126784 images, 0.181729 hours left
# Loaded: 0.000081 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.870151), count: 1, class_loss = 0.000005, iou_loss = 0.084834, total_loss = 0.084839
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000007, iou_loss = 0.000000, total_loss = 0.000007
# ...
