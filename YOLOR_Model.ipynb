# %% [markdown]
# The reference for this YOLOR model configuration for our datasets is taken from the tutorial links https://www.youtube.com/watch?v=h_Ookqy0K2Y and https://github.com/WongKinYiu/yolor

# %%
# !nvidia-smi
# Out:
# Sun May  8 16:21:04 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp -R /content/gdrive/MyDrive/yolor-main /content/

# %%
pip install -U PyYAML
# Out:
# ...
#      |████████████████████████████████| 596 kB 8.5 MB/s
# ...
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
pip install git+https://github.com/philferriere/cocoapi.git#subdirectory=PythonAPI
# Out:
# ...
#   Cloning https://github.com/philferriere/cocoapi.git to /tmp/pip-req-build-_f6a2_7z
#   Running command git clone -q https://github.com/philferriere/cocoapi.git /tmp/pip-req-build-_f6a2_7z
# ...
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp37-cp37m-linux_x86_64.whl size=264422 sha256=12dcd6f96cade4e30e29c7566e9724e021e0605b5b802aba8d17c26bab1ad307
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pv7u2mn4/wheels/6b/c6/c5/cb6da4cb793a6cb1ab91f6578d76c42686422127eb4dbcea94
# Successfully built pycocotools
# ...
#   Attempting uninstall: pycocotools
#     Found existing installation: pycocotools 2.0.4
#     Uninstalling pycocotools-2.0.4:
#       Successfully uninstalled pycocotools-2.0.4
# ...

# %%
#!cp -R /content/Kvasir-SEG-format/images /content/yolor-main/dataset

# %%
# !cp -R /content/runs/train/yolor_p6/weights /content/gdrive/MyDrive/YOLORruns
# Out:
# cp: cannot stat '/content/runs/train/yolor_p6/weights': No such file or directory

# %%
# !python /content/yolor-main/train.py --batch-size 16 --img 640 640 --data /content/yolor-main/data/polyp.yaml \
 --device 0 --cfg /content/yolor-main/cfg/yolor_p6-polyp.cfg --weights '' --name yolor_p6 --hyp /content/yolor-main/data/hyp.scratch.640.yaml --epochs 300
# Out:
# Using torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16280MB)
#
# Namespace(adam=False, batch_size=16, bucket='', cache_images=False, cfg='/content/yolor-main/cfg/yolor_p6-polyp.cfg', data='/content/yolor-main/data/polyp.yaml', device='0', epochs=300, evolve=False, exist_ok=False, global_rank=-1, hyp='/content/yolor-main/data/hyp.scratch.640.yaml', image_weights=False, img_size=[640, 640], local_rank=-1, log_imgs=16, multi_scale=False, name='yolor_p6', noautoanchor=False, nosave=False, notest=False, project='runs/train', rect=False, resume=False, save_dir='runs/train/yolor_p6', single_cls=False, sync_bn=False, total_batch_size=16, weights='', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# ...

# %%
# !pip install wandb
# !wandb login
# Out:
# ...
# wandb: Currently logged in as: amitapatra (use `wandb login --relogin` to force relogin)

# %%
# !pip install -q wandb
import wandb
wandb.login()
# Out:
#      |████████████████████████████████| 1.8 MB 7.5 MB/s
#      |████████████████████████████████| 144 kB 60.7 MB/s
#      |████████████████████████████████| 181 kB 50.3 MB/s
#      |████████████████████████████████| 63 kB 1.4 MB/s
# ...
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# !python /content/yolor-main/train.py --batch-size 16 --img 640 640 --data /content/yolor-main/data/polyp.yaml \
 --device 0 --cfg /content/yolor-main/cfg/yolor_p6-polyp.cfg --weights '' --name yolor_p6 --hyp /content/yolor-main/data/hyp.scratch.640.yaml --epochs 300
# Out:
# Using torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16280MB)
#
# Namespace(adam=False, batch_size=16, bucket='', cache_images=False, cfg='/content/yolor-main/cfg/yolor_p6-polyp.cfg', data='/content/yolor-main/data/polyp.yaml', device='0', epochs=300, evolve=False, exist_ok=False, global_rank=-1, hyp='/content/yolor-main/data/hyp.scratch.640.yaml', image_weights=False, img_size=[640, 640], local_rank=-1, log_imgs=16, multi_scale=False, name='yolor_p6', noautoanchor=False, nosave=False, notest=False, project='runs/train', rect=False, resume=False, save_dir='runs/train/yolor_p6', single_cls=False, sync_bn=False, total_batch_size=16, weights='', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# ...

# %%
# !python /content/yolor-main/train.py --batch-size 16 --img 640 640 --data /content/yolor-main/data/polyp.yaml \
 --device 0 --cfg /content/yolor-main/cfg/yolor_p6-polyp.cfg --weights '' --name yolor_p6 --hyp /content/yolor-main/data/hyp.scratch.640.yaml --epochs 300
# Out:
# Using torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16280MB)
#
# Namespace(adam=False, batch_size=16, bucket='', cache_images=False, cfg='/content/yolor-main/cfg/yolor_p6-polyp.cfg', data='/content/yolor-main/data/polyp.yaml', device='0', epochs=300, evolve=False, exist_ok=False, global_rank=-1, hyp='/content/yolor-main/data/hyp.scratch.640.yaml', image_weights=False, img_size=[640, 640], local_rank=-1, log_imgs=16, multi_scale=False, name='yolor_p6', noautoanchor=False, nosave=False, notest=False, project='runs/train', rect=False, resume=False, save_dir='runs/train/yolor_p62', single_cls=False, sync_bn=False, total_batch_size=16, weights='', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# ...

# %%
# !zip -r /content/file.zip /runs/train

from google.colab import files
files.download("/content/file.zip")

# %%
# !zip -r /content/file.zip ./runs/train/yolor_p6
# Out:
#   adding: runs/train/yolor_p6/ (stored 0%)
#   adding: runs/train/yolor_p6/test_batch2_pred.jpg (deflated 4%)
#   adding: runs/train/yolor_p6/test_batch2_labels.jpg (deflated 4%)
#   adding: runs/train/yolor_p6/labels_correlogram.png (deflated 6%)
#   adding: runs/train/yolor_p6/results.txt (deflated 79%)
#   adding: runs/train/yolor_p6/test_batch1_labels.jpg (deflated 5%)
#   adding: runs/train/yolor_p6/train_batch1.jpg (deflated 7%)
#   adding: runs/train/yolor_p6/precision-recall_curve.png (deflated 15%)
#   adding: runs/train/yolor_p6/test_batch0_pred.jpg (deflated 10%)
#   adding: runs/train/yolor_p6/results.png (deflated 9%)
#   adding: runs/train/yolor_p6/hyp.yaml (deflated 43%)
#   adding: runs/train/yolor_p6/weights/ (stored 0%)
#   adding: runs/train/yolor_p6/weights/epoch_199.pt (deflated 25%)
#   adding: runs/train/yolor_p6/weights/epoch_274.pt (deflated 25%)
#   adding: runs/train/yolor_p6/weights/epoch_224.pt (deflated 25%)
# ...

# %%
from google.colab import files
files.download("/content/file.zip")

# %%
# !python /content/yolor-main/test.py --batch-size 16 --img 640  --data /content/yolor-main/data/polyp.yaml \
 --device 0 --cfg /content/yolor-main/cfg/yolor_p6-polyp.cfg --weights /content/runs/train/yolor_p6/weights/best.pt --name yolor_p6
# Out:
# Namespace(augment=False, batch_size=16, cfg='/content/yolor-main/cfg/yolor_p6-polyp.cfg', conf_thres=0.001, data='/content/yolor-main/data/polyp.yaml', device='0', exist_ok=False, img_size=640, iou_thres=0.65, name='yolor_p6', names='/content/yolor-main/data/polyp.names', project='runs/test', save_conf=False, save_json=True, save_txt=False, single_cls=False, task='val', verbose=False, weights=['/content/runs/train/yolor_p6/weights/best.pt'])
# Using torch 1.10.0+cu111 CUDA:0 (Tesla T4, 15109MB)
#
# Model Summary: 665 layers, 36838416 parameters, 36838416 gradients
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
#from google.colab import drive
#drive.flush_and_unmount()

# %%
#pip install -U PyYAML
# Out:
# ...
#      |████████████████████████████████| 596 kB 8.4 MB/s
# ...
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# !cp -R  /content/runs/ /content/gdrive/MyDrive/Yolor-runs

# %%
# !zip -r /content/file.zip /content/yolor-main/cfg/

from google.colab import files
files.download("/content/file.zip")
# Out:
# updating: content/yolor-main/cfg/ (stored 0%)
# updating: content/yolor-main/cfg/yolor_p6.cfg (deflated 92%)
# updating: content/yolor-main/cfg/yolov4_p7.cfg (deflated 95%)
# updating: content/yolor-main/cfg/yolor_csp_x.cfg (deflated 92%)
# updating: content/yolor-main/cfg/yolor_w6.cfg (deflated 92%)
# updating: content/yolor-main/cfg/yolov4_csp_x.cfg (deflated 92%)
# updating: content/yolor-main/cfg/yolov4_csp.cfg (deflated 91%)
# updating: content/yolor-main/cfg/.ipynb_checkpoints/ (stored 0%)
# updating: content/yolor-main/cfg/yolor_csp.cfg (deflated 90%)
# updating: content/yolor-main/cfg/yolor_p6-polyp.cfg (deflated 92%)
# updating: content/yolor-main/cfg/yolov4_p6.cfg (deflated 94%)

# %%
# !cp -R  /content/yolor-main  /content/gdrive/MyDrive/

# %%
#!bash /content/yolor-main/scripts/get_coco.sh
# Out:
# ...
#     % Total    % Receiv  %ed % Xferd  Average S%pee dT o t aTli m e    %   RTeicmeei v e d    % Xferd  TiTmeot  alCu  rr  en% t
# Re Ace  ivveed   %ra X  fegerd             Av Ser  agpee   Spedee  d       Ti Tme    im    Tie me           T TimDle im Coaure red nt
#   U      pl  Ti  oa  me  d           C To%ta Tur  l otre      Spalen  nt  t
#          %  L    ReefDl  cet oa  iv Sd   edpe U   %edpl   X
# ad  fe      rd   T0     ot  Av  al  er    0 ag   S  e   pe 0Sp  nt  eeDl    d oa   0  d Le  Ti Uft  mepl  0   oaSp    d Ti  ee  meTod
#  l      T   0  imSp  0 e en     Ct  0  ur     0re L   -ntef0 -:
#  t   --   S  :-  pe0 -   ed  --
#   :-0 -:      -- - 0  0  -:     --   0  :-      -     0     0           0     0     0  --  D  lo0:   --  a0 d   :   Upload   Total   Spent    Left  Speed
# 100   657  100   657    0     0   3143      0 --:--:-- --:--:-- --:--:--  3143
# 100 67.7M  100 67.7M    0     0  11.6M      0  0:00:05  0:00:05 --:--:-- 12.1M
# ...

# %%
import wandb
wandb.finish()

# %%
#base training test iou0.6
# !python /content/yolor-main/test.py --batch-size 16 --img 640  --data /content/yolor-main/data/polyp.yaml \
 --device 0 --cfg /content/yolor-main/cfg/yolor_p6-polyp.cfg --weights /content/yolor-main/weights/best.pt --name yolor_p6
# Out:
# Namespace(augment=False, batch_size=16, cfg='/content/yolor-main/cfg/yolor_p6-polyp.cfg', conf_thres=0.001, data='/content/yolor-main/data/polyp.yaml', device='0', exist_ok=False, img_size=640, iou_thres=0.65, name='yolor_p6', names='/content/yolor-main/data/polyp.names', project='runs/test', save_conf=False, save_json=True, save_txt=False, single_cls=False, task='val', verbose=False, weights=['/content/yolor-main/weights/best.pt'])
# Using torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16280MB)
#
# Model Summary: 665 layers, 36838416 parameters, 36838416 gradients
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
#base training val iou0.25
# !python /content/yolor-main/test.py --batch-size 16 --img 640  --data /content/yolor-main/data/polyp.yaml \
 --device 0 --cfg /content/yolor-main/cfg/yolor_p6-polyp.cfg --weights /content/yolor-main/weights/best.pt --name yolor_p6
# Out:
# Namespace(augment=False, batch_size=16, cfg='/content/yolor-main/cfg/yolor_p6-polyp.cfg', conf_thres=0.001, data='/content/yolor-main/data/polyp.yaml', device='0', exist_ok=False, img_size=640, iou_thres=0.25, name='yolor_p6', names='/content/yolor-main/data/polyp.names', project='runs/test', save_conf=False, save_json=True, save_txt=False, single_cls=False, task='val', verbose=False, weights=['/content/yolor-main/weights/best.pt'])
# Using torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16280MB)
#
# Model Summary: 665 layers, 36838416 parameters, 36838416 gradients
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
#base training test iou0.25
# !python /content/yolor-main/test.py  --data /content/yolor-main/data/polyp.yaml \
 --device 0 --cfg /content/yolor-main/cfg/yolor_p6-polyp.cfg --weights /content/yolor-main/weights/best.pt --name yolor_p6
# Out:
# Namespace(augment=False, batch_size=32, cfg='/content/yolor-main/cfg/yolor_p6-polyp.cfg', conf_thres=0.001, data='/content/yolor-main/data/polyp.yaml', device='0', exist_ok=False, img_size=1280, iou_thres=0.25, name='yolor_p6', names='/content/yolor-main/data/polyp.names', project='runs/test', save_conf=False, save_json=True, save_txt=False, single_cls=False, task='val', verbose=False, weights=['/content/yolor-main/weights/best.pt'])
# Using torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16280MB)
#
# Model Summary: 665 layers, 36838416 parameters, 36838416 gradients
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
#base training val iou0.5
# !python /content/yolor-main/test.py --batch-size 16 --img 640  --data /content/yolor-main/data/polyp.yaml \
 --device 0 --cfg /content/yolor-main/cfg/yolor_p6-polyp.cfg --weights /content/yolor-main/weights/best.pt --name yolor_p6

# %%
#base training test iou0.25
# !python /content/yolor-main/test.py --batch-size 16 --img 640  --data /content/yolor-main/data/polyp.yaml \
 --device 0 --cfg /content/yolor-main/cfg/yolor_p6-polyp.cfg --weights /content/yolor-main/weights/best.pt --name yolor_p6

# %%
#base training val iou0.75
# !python /content/yolor-main/test.py --batch-size 16 --img 640  --data /content/yolor-main/data/polyp.yaml \
 --device 0 --cfg /content/yolor-main/cfg/yolor_p6-polyp.cfg --weights /content/yolor-main/weights/best.pt --name yolor_p6

# %%
#base training test iou0.75
# !python /content/yolor-main/test.py --batch-size 16 --img 640  --data /content/yolor-main/data/polyp.yaml \
 --device 0 --cfg /content/yolor-main/cfg/yolor_p6-polyp.cfg --weights /content/yolor-main/weights/best.pt --name yolor_p6

# %%
#test images path for yolor - test.txt
from torchvision.io import read_image
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from torchvision.ops import masks_to_boxes
from PIL import Image
from pathlib import Path

path = "/content/yolor-main/dataset/images/test/"
os.chdir(path)

file1 = open("/content/yolor-main/dataset/test.txt", "w") 

for file in os.listdir():
    # Check whether file is in text format or not
    file1.write(path+Path(file).stem + '.jpg'+ '\n')

file1.close()

# %%
#test images path for yolor - test.txt
from torchvision.io import read_image
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from torchvision.ops import masks_to_boxes
from PIL import Image
from pathlib import Path

path = "/content/yolor-main/dataset/images/test/"
os.chdir(path)

file1 = open("/content/yolor-main/dataset/test.txt", "w") 

for file in os.listdir():
    # Check whether file is in text format or not
    file1.write(path+Path(file).stem + '.jpg'+ '\n')

file1.close()

# %%
 #Train the model with negative training

# !python /content/yolor-main/train.py --batch-size 32 --img 640 640 --data /content/yolor-main/data/polyp.yaml \
 --device 0 --cfg /content/yolor-main/cfg/yolor_p6-polyp.cfg --weights '' --name yolor_p6 --hyp /content/yolor-main/data/hyp.scratch.640.yaml --epochs 300
# Out:
# Using torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16280MB)
#
# Namespace(adam=False, batch_size=32, bucket='', cache_images=False, cfg='/content/yolor-main/cfg/yolor_p6-polyp.cfg', data='/content/yolor-main/data/polyp.yaml', device='0', epochs=300, evolve=False, exist_ok=False, global_rank=-1, hyp='/content/yolor-main/data/hyp.scratch.640.yaml', image_weights=False, img_size=[640, 640], local_rank=-1, log_imgs=16, multi_scale=False, name='yolor_p6', noautoanchor=False, nosave=False, notest=False, project='runs/train', rect=False, resume=False, save_dir='runs/train/yolor_p62', single_cls=False, sync_bn=False, total_batch_size=32, weights='', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# ...

# %%
# !cp -R /content/yolor-main/dataset/images/train/wandb/run-20220424_083232-1pumt3gz /content/gdrive/MyDrive/yolor_negative/

# %%
#base training val iou0.5
# !python /content/yolor-main/test.py --batch-size 16 --img 640  --data /content/yolor-main/data/polyp.yaml \
 --device 0 --cfg /content/yolor-main/cfg/yolor_p6-polyp.cfg --weights /content/yolor-main/weights/best.pt --name yolor_p6

# %%
#base training val iou0.75
# !python /content/yolor-main/test.py --batch-size 16 --img 640  --data /content/yolor-main/data/polyp.yaml \
 --device 0 --cfg /content/yolor-main/cfg/yolor_p6-polyp.cfg --weights /content/yolor-main/weights/best.pt --name yolor_p6

# %%
#base training val iou0.25
# !python /content/yolor-main/test.py --batch-size 16 --img 640  --data /content/yolor-main/data/polyp.yaml \
 --device 0 --cfg /content/yolor-main/cfg/yolor_p6-polyp.cfg --weights /content/yolor-main/weights/best.pt --name yolor_p6

# %%
#base training val iou0.25
# !python /content/yolor-main/test.py --batch-size 16 --img 640  --data /content/yolor-main/data/polyp.yaml \
 --device 0 --cfg /content/yolor-main/cfg/yolor_p6-polyp.cfg --weights /content/yolor-main/dataset/weights/best.pt --name yolor_p6
# Out:
# Namespace(augment=False, batch_size=16, cfg='/content/yolor-main/cfg/yolor_p6-polyp.cfg', conf_thres=0.001, data='/content/yolor-main/data/polyp.yaml', device='0', exist_ok=False, img_size=640, iou_thres=0.25, name='yolor_p6', names='/content/yolor-main/data/polyp.names', project='runs/test', save_conf=False, save_json=True, save_txt=False, single_cls=False, task='val', verbose=False, weights=['/content/yolor-main/dataset/weights/best.pt'])
# Using torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16280MB)
#
# Model Summary: 665 layers, 36838416 parameters, 36838416 gradients
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
#base training val iou0.5
# !python /content/yolor-main/test.py --batch-size 16 --img 640  --data /content/yolor-main/data/polyp.yaml \
 --device 0 --cfg /content/yolor-main/cfg/yolor_p6-polyp.cfg --weights /content/yolor-main/dataset/weights/best.pt --name yolor_p6
# Out:
# Namespace(augment=False, batch_size=16, cfg='/content/yolor-main/cfg/yolor_p6-polyp.cfg', conf_thres=0.001, data='/content/yolor-main/data/polyp.yaml', device='0', exist_ok=False, img_size=640, iou_thres=0.5, name='yolor_p6', names='/content/yolor-main/data/polyp.names', project='runs/test', save_conf=False, save_json=True, save_txt=False, single_cls=False, task='val', verbose=False, weights=['/content/yolor-main/dataset/weights/best.pt'])
# Using torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16280MB)
#
# Model Summary: 665 layers, 36838416 parameters, 36838416 gradients
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
#base training val iou0.75
# !python /content/yolor-main/test.py --batch-size 16 --img 640  --data /content/yolor-main/data/polyp.yaml \
 --device 0 --cfg /content/yolor-main/cfg/yolor_p6-polyp.cfg --weights /content/yolor-main/dataset/weights/best.pt --name yolor_p6
# Out:
# Namespace(augment=False, batch_size=16, cfg='/content/yolor-main/cfg/yolor_p6-polyp.cfg', conf_thres=0.001, data='/content/yolor-main/data/polyp.yaml', device='0', exist_ok=False, img_size=640, iou_thres=0.75, name='yolor_p6', names='/content/yolor-main/data/polyp.names', project='runs/test', save_conf=False, save_json=True, save_txt=False, single_cls=False, task='val', verbose=False, weights=['/content/yolor-main/dataset/weights/best.pt'])
# Using torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16280MB)
#
# Model Summary: 665 layers, 36838416 parameters, 36838416 gradients
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
#base training detect iou0.25
# !python /content/yolor-main/test.py --batch-size 16 --img 640  --data /content/yolor-main/data/polyp.yaml \
 --device 0 --cfg /content/yolor-main/cfg/yolor_p6-polyp.cfg --weights /content/yolor-main/dataset/weights/best.pt --name yolor_p6
# Out:
# Namespace(augment=False, batch_size=16, cfg='/content/yolor-main/cfg/yolor_p6-polyp.cfg', conf_thres=0.001, data='/content/yolor-main/data/polyp.yaml', device='0', exist_ok=False, img_size=640, iou_thres=0.25, name='yolor_p6', names='/content/yolor-main/data/polyp.names', project='runs/test', save_conf=False, save_json=True, save_txt=False, single_cls=False, task='val', verbose=False, weights=['/content/yolor-main/dataset/weights/best.pt'])
# Using torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16280MB)
#
# Model Summary: 665 layers, 36838416 parameters, 36838416 gradients
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
#base training detect iou0.5
# !python /content/yolor-main/test.py --batch-size 16 --img 640  --data /content/yolor-main/data/polyp.yaml \
 --device 0 --cfg /content/yolor-main/cfg/yolor_p6-polyp.cfg --weights /content/yolor-main/dataset/weights/best.pt --name yolor_p6
# Out:
# Namespace(augment=False, batch_size=16, cfg='/content/yolor-main/cfg/yolor_p6-polyp.cfg', conf_thres=0.001, data='/content/yolor-main/data/polyp.yaml', device='0', exist_ok=False, img_size=640, iou_thres=0.5, name='yolor_p6', names='/content/yolor-main/data/polyp.names', project='runs/test', save_conf=False, save_json=True, save_txt=False, single_cls=False, task='val', verbose=False, weights=['/content/yolor-main/dataset/weights/best.pt'])
# Using torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16280MB)
#
# Model Summary: 665 layers, 36838416 parameters, 36838416 gradients
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
#base training detect iou0.75
# !python /content/yolor-main/test.py --batch-size 16 --img 640  --data /content/yolor-main/data/polyp.yaml \
 --device 0 --cfg /content/yolor-main/cfg/yolor_p6-polyp.cfg --weights /content/yolor-main/dataset/weights/best.pt --name yolor_p6
# Out:
# Namespace(augment=False, batch_size=16, cfg='/content/yolor-main/cfg/yolor_p6-polyp.cfg', conf_thres=0.001, data='/content/yolor-main/data/polyp.yaml', device='0', exist_ok=False, img_size=640, iou_thres=0.75, name='yolor_p6', names='/content/yolor-main/data/polyp.names', project='runs/test', save_conf=False, save_json=True, save_txt=False, single_cls=False, task='val', verbose=False, weights=['/content/yolor-main/dataset/weights/best.pt'])
# Using torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16280MB)
#
# Model Summary: 665 layers, 36838416 parameters, 36838416 gradients
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
#base training detect iou0.75
# !python /content/yolor-main/detect.py --img 640  --iou-thres 0.5\
 --device 0 --cfg /content/yolor-main/cfg/yolor_p6-polyp.cfg --weights /content/yolor-main/dataset/weights/best.pt --name /content/yolor-main/data/polyp.names
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='/content/yolor-main/cfg/yolor_p6-polyp.cfg', classes=None, conf_thres=0.4, device='0', img_size=640, iou_thres=0.5, names='/content/yolor-main/data/polyp.names', output='inference/output', save_txt=False, source='inference/images', update=False, view_img=False, weights=['/content/yolor-main/dataset/weights/best.pt'])
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# image 1/8 /content/yolor-main/dataset/images/test/inference/images/01e16988-9c35-473e-912c-ad3897fb4c9a.jpg: 512x640 1 polyps, Done. (0.051s)
# image 2/8 /content/yolor-main/dataset/images/test/inference/images/0b631ace-98b7-46dc-938c-bab783e3ce8c.jpg: 512x640 2 polyps, Done. (0.050s)
# ...

# %%
#retrain
# !python /content/yolor-main/train.py --batch-size 16 --img 640 640 --data /content/yolor-main/data/polyp.yaml \
 --device 0 --cfg /content/yolor-main/cfg/yolor_p6-polyp.cfg --weights /content/yolor-main/best_overall.pt --name yolor_p6 --hyp /content/yolor-main/data/hyp.scratch.640.yaml --epochs 550
# Out:
# Using torch 1.11.0+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16280MB)
#
# Namespace(adam=False, batch_size=16, bucket='', cache_images=False, cfg='/content/yolor-main/cfg/yolor_p6-polyp.cfg', data='/content/yolor-main/data/polyp.yaml', device='0', epochs=550, evolve=False, exist_ok=False, global_rank=-1, hyp='/content/yolor-main/data/hyp.scratch.640.yaml', image_weights=False, img_size=[640, 640], local_rank=-1, log_imgs=16, multi_scale=False, name='yolor_p6', noautoanchor=False, nosave=False, notest=False, project='runs/train', rect=False, resume=False, save_dir='runs/train/yolor_p64', single_cls=False, sync_bn=False, total_batch_size=16, weights='/content/yolor-main/best_overall.pt', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# NumExpr defaulting to 4 threads.
# ...
